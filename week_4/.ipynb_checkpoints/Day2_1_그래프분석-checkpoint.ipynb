# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
import matplotlib.font_manager as fm
for f in fm.fontManager.ttflist:
    if 'NanumBarunGothic' in f.fname: plt.rcParams['font.family']='NanumBarunGothic'
    # 폰트 나눔고딕으로

print(plt.rcParams['font.family'])

matplotlib.rcParams['axes.unicode_minus'] = False # '-'기호 제대로 나오게
# Out:
# ['NanumBarunGothic']

# %%
ds_fitness = pd.read_csv("./FITNESS.csv", engine="python",encoding='euc-kr')
ds_fitness.head()
# Out:
#      NAME GENDER  AGE AGEGROUP  WEIGHT     OXY  RUNTIME  RUNPULSE  RSTPULSE  \
# 0   Donna     여성   42      40대   68.15  59.571     8.17       166        40
# 1  Gracie    NaN   38      30대   81.87  60.055     8.63       170        48
# 2  Luanne     여성   43      40대   85.84  54.297     8.65       156        45
# 3    Mimi     여성   50      50대   70.87  54.625     8.92       146        48
# 4   Chris     남성   49      40대     NaN  49.156     8.95       180        44
#
#    MAXPULSE
# 0       172
# 1       186
# 2       168
# 3       155
# 4       185

# %%
ds_currency = pd.read_csv("./환율.csv", engine="python", parse_dates=["APPL_DATE"])
ds_currency.head()
# Out:
#   CURRENCY  APPL_DATE  STD_RATE  USD_CONV_DATE
# 0      CNY 2016-01-01    181.48         0.1541
# 1      JPY 2016-01-01    976.99         0.8294
# 2      USD 2016-01-01   1178.00         1.0000
# 3      CNY 2016-01-02    181.48         0.1541
# 4      JPY 2016-01-02    976.99         0.8294

# %% [markdown]
# ___

# %% [markdown]
# ## Bar Chart

# %%
ds_agg = ds_fitness["AGEGROUP"].value_counts()
ds_agg.sort_index(inplace=True, ascending=False)
ds_agg.plot.bar()

# %%
ds_agg = ds_fitness["AGEGROUP"].value_counts()
ds_agg.sort_index(inplace=True, ascending=True)
ds_agg.plot.bar()

# %%
ds_agg = ds_fitness["AGEGROUP"].value_counts(ascending=True)
ds_agg.plot.bar()

# %%
ds_agg = ds_fitness["AGEGROUP"].value_counts()
ds_agg.plot.bar()

# %% [markdown]
# ___

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### 혈당 산소 요구량 Histogram 생성

# %%
ds_fitness["OXY"].hist()

# %% [markdown]
# ### 여러 변수 Histogram 생성

# %%
ds_fitness[["WEIGHT","AGE","OXY","RUNTIME"]].hist(figsize=(10,4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff4f6001f28>,
# ...
#       dtype=object)

# %% [markdown]
# ### 성별 혈당 산소 요구량 Histogram 생성

# %%
grid = sns.FacetGrid(ds_fitness,col='GENDER')
grid.map(plt.hist,"OXY")

# %% [markdown]
# ### 성별 혈당 산소 요구량 중첩 Histogram 생성

# %%
plt.hist(ds_fitness[ds_fitness["GENDER"] == '남성']["OXY"], label="남성", alpha=0.5)
plt.hist(ds_fitness[ds_fitness["GENDER"] == '여성']["OXY"], label="여성", alpha=0.5)
plt.legend()

# %% [markdown]
# > 여성과 남성에 대한 혈당 산소 요구량에 대한 히트토그램을 확인
# >>남성이 더 낮은 범위의 혈당 선소 요구량을 보여줌

# %% [markdown]
# ### 성별 혈당 산소 요구량 중첩 Histogram 생성

# %%
plt.hist(x="OXY", data=ds_fitness)
# Out:
# (array([4., 1., 0., 9., 6., 6., 1., 2., 0., 2.]),
#  array([37.388 , 39.6547, 41.9214, 44.1881, 46.4548, 48.7215, 50.9882,
#         53.2549, 55.5216, 57.7883, 60.055 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(x="OXY", data=ds_fitness, bins=20)
# Out:
# (array([1., 3., 0., 1., 0., 0., 5., 4., 4., 2., 2., 4., 1., 0., 1., 1., 0.,
#         0., 0., 2.]),
#  array([37.388  , 38.52135, 39.6547 , 40.78805, 41.9214 , 43.05475,
#         44.1881 , 45.32145, 46.4548 , 47.58815, 48.7215 , 49.85485,
#         50.9882 , 52.12155, 53.2549 , 54.38825, 55.5216 , 56.65495,
#         57.7883 , 58.92165, 60.055  ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(x="OXY", data=ds_fitness, bins=20,density=True)
# Out:
# (array([0.02846258, 0.08538774, 0.        , 0.02846258, 0.        ,
#         0.        , 0.1423129 , 0.11385032, 0.11385032, 0.05692516,
#         0.05692516, 0.11385032, 0.02846258, 0.        , 0.02846258,
#         0.02846258, 0.        , 0.        , 0.        , 0.05692516]),
#  array([37.388  , 38.52135, 39.6547 , 40.78805, 41.9214 , 43.05475,
#         44.1881 , 45.32145, 46.4548 , 47.58815, 48.7215 , 49.85485,
#         50.9882 , 52.12155, 53.2549 , 54.38825, 55.5216 , 56.65495,
#         57.7883 , 58.92165, 60.055  ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(x="OXY", data=ds_fitness, bins=20, cumulative=True)
# Out:
# (array([ 1.,  4.,  4.,  5.,  5.,  5., 10., 14., 18., 20., 22., 26., 27.,
#         27., 28., 29., 29., 29., 29., 31.]),
#  array([37.388  , 38.52135, 39.6547 , 40.78805, 41.9214 , 43.05475,
#         44.1881 , 45.32145, 46.4548 , 47.58815, 48.7215 , 49.85485,
#         50.9882 , 52.12155, 53.2549 , 54.38825, 55.5216 , 56.65495,
#         57.7883 , 58.92165, 60.055  ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(x="OXY", data=ds_fitness, bins=20, orientation="horizontal")
# Out:
# (array([1., 3., 0., 1., 0., 0., 5., 4., 4., 2., 2., 4., 1., 0., 1., 1., 0.,
#         0., 0., 2.]),
#  array([37.388  , 38.52135, 39.6547 , 40.78805, 41.9214 , 43.05475,
#         44.1881 , 45.32145, 46.4548 , 47.58815, 48.7215 , 49.85485,
#         50.9882 , 52.12155, 53.2549 , 54.38825, 55.5216 , 56.65495,
#         57.7883 , 58.92165, 60.055  ]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(x="OXY", data=ds_fitness, bins=20, orientation='bar')
# {'bar', 'barstacked', 'step',  'stepfilled'}
# Out:
# (array([ 1.,  4.,  4.,  5.,  5.,  5., 10., 14., 18., 20., 22., 26., 27.,
#         27., 28., 29., 29., 29., 29., 31.]),
#  array([37.388  , 38.52135, 39.6547 , 40.78805, 41.9214 , 43.05475,
#         44.1881 , 45.32145, 46.4548 , 47.58815, 48.7215 , 49.85485,
#         50.9882 , 52.12155, 53.2549 , 54.38825, 55.5216 , 56.65495,
#         57.7883 , 58.92165, 60.055  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# ## Box Plot

# %% [markdown]
# ### 정의
# > 데이터의 분포나 범주형 변수의 수준별 데이터 분포를 상자/수염으로 표현하는 그래프

# %% [markdown]
# ### 연령대별 몸부게 분포를 Box plot 생성

# %%
df_fitness.boxplot(column="WEIGHT",by="AGEGROUP")

# %% [markdown]
# > 30대의 몸무게 중앙값이 가장 높고
# 40대는 분포가 넓고
# 50대는 중앙값은 낮으나 분포도 넓고 이상치도 포함되어있음

# %% [markdown]
# ___

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# > 구성 요소별 비율을 부채꼴 모양으로 나타낸 그래프로 각 부채꼴의 각이 자너체에서 차지하는 비율을 나타냄

# %% [markdown]
# ### 혈당산소 요구량이 50이상인 나이 그룹별 현황을 Pie Chart로 생성

# %%
ds_sub = df_fitness[ds_fitness["OXY"]>=50]
ds_count = ds_sub.groupby("AGEGROUP", as_index=False).agg("count")
ds_count.plot.pie(y="OXY",labels=ds_count["AGEGROUP"],autopct="%.1f%%").legend(loc="upper right")

# %% [markdown]
# ___

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# > x,y 좌표를 이용해 두 변수(일반적으로 숫자 변수)간의 관계를 나타낸 그래프

# %% [markdown]
# ### 운동시간과 운동 중 맥박수 간의 Scatter Plot생성

# %%
sns.scatterplot(x ="RUNTIME", y="RUNPULSE",hue="GENDER",data=ds_fitness)

# %% [markdown]
# > 맥박은 운동시간에 비례해서 증가.
# 남녀별 큰 차이 없음

# %% [markdown]
# ___

# %% [markdown]
# ## Scatter Matrix

# %% [markdown]
# > 다수의 변수들 간의 관계를 한눈에 파악하는데 유용하게 시각화 한 그래프

# %% [markdown]
# ### 운동중 맥박, 최대 백박, 혈당 산소 요구량, 운동시간 간의 Scatter Matrix생성

# %%
ds_filter = ds_fitness.filter(["RUNPULSE","MAXPULSE","OXY","RUNTIME"])
sns.pairplot(ds_filter)

# %% [markdown]
# > 운동맥박과 최대맥박은 양의 선형관계가 있고, 운동시간과 혈당 산소 요구량은 음의 성현 관계가 있음

# %%
# ds_filter = ds_fitness.filter(["RUNPULSE","MAXPULSE","OXY","RUNTIME"])
sns.pairplot(ds_fitness)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:754: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/pirl/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:755: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ___

# %% [markdown]
# ## Trend Chart

# %% [markdown]
# > x축의 값(보통 시간, 가격)의 변화에 따른 y축 값의 변화, 즉 추세를 나타낸 그래프

# %% [markdown]
# ### 통화 별로 매매 기준율에 대한 Trend Chart 생성

# %%
ds_currency.head(5)
# Out:
#   CURRENCY  APPL_DATE  STD_RATE  USD_CONV_DATE
# 0      CNY 2016-01-01    181.48         0.1541
# 1      JPY 2016-01-01    976.99         0.8294
# 2      USD 2016-01-01   1178.00         1.0000
# 3      CNY 2016-01-02    181.48         0.1541
# 4      JPY 2016-01-02    976.99         0.8294

# %%
ds_currency_pivot = ds_currency.pivot(index="APPL_DATE", columns="CURRENCY",values="STD_RATE")

# %%
ds_currency_pivot["CNY"].plot()

# %%
 ds_currency_pivot[["JPY","USD"]].plot()

# %%
 ds_currency_pivot[["JPY","USD","CNY"]].plot()

# %% [markdown]
# > 스케일이 맞지 않아 인사이트 도출에 의미가 거의 없는 그래프이다.

# %% [markdown]
# ___

# %% [markdown]
# ## Heatmap

# %% [markdown]
# > 좌표축 위에 색상으로 값을 표현한 그래플 열(heat)과 지도를 결합시킨 단어

# %% [markdown]
# ### 성별과 나이그룹별 혈당 산소 유구량 현황 Heatmap 생성

# %%
ds_agg = ds_fitness.groupby(["GENDER","AGEGROUP"],as_index=False).agg('mean')
ds_pivot = ds_agg.pivot("GENDER", "AGEGROUP","OXY")
sns.heatmap(ds_pivot,cmap="Blues")

# %% [markdown]
# ___

# %% [markdown]
# ## Contour Plot

# %% [markdown]
# > 등고선 도표로 x,y축의 숫자형 자료 값에 대응하는 Z값을 등고선과 색깔로 나타낸 그래프
# >> 자료의 분포 밀도와 영역을 쉽게 확인

# %% [markdown]
# ### 운동시간과 운동맥박 Contour Plot생성

# %%
sns.kdeplot(ds_fitness["RUNTIME"],ds_fitness["RUNPULSE"],shade=False)
# Out:
# /home/pirl/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.kdeplot(ds_fitness["RUNTIME"],ds_fitness["RUNPULSE"],shade=True)

# %% [markdown]
# ---

# %% [markdown]
# ## Parallel Plot

# %% [markdown]
# > 등고선 도표로 x,y축의 숫자형 자료 값에 대응하는 Z값을 등고선과 색깔로 나타낸 그래프
# >> 자료의 분포 밀도와 영역을 쉽게 확인

# %% [markdown]
# ## 성별에 따른 혈당 산소 요구량, 몸무게, 휴식 시 맥박수 Parallel Plot 생성

# %%
ds_fitness.GENDER.fillna("여성", inplace=True)
ds_fitness.head(5)
# Out:
#      NAME GENDER  AGE AGEGROUP  WEIGHT     OXY  RUNTIME  RUNPULSE  RSTPULSE  \
# 0   Donna     여성   42      40대   68.15  59.571     8.17       166        40
# 1  Gracie     여성   38      30대   81.87  60.055     8.63       170        48
# 2  Luanne     여성   43      40대   85.84  54.297     8.65       156        45
# 3    Mimi     여성   50      50대   70.87  54.625     8.92       146        48
# 4   Chris     남성   49      40대     NaN  49.156     8.95       180        44
#
#    MAXPULSE
# 0       172
# 1       186
# 2       168
# 3       155
# 4       185

# %%
ds_filter = ds_fitness[["GENDER","OXY","WEIGHT","RSTPULSE"]]
pd.plotting.parallel_coordinates(ds_filter, "GENDER",color=("RED","GREEN"))

# %% [markdown]
# > 남성은 여성에 비해 몸무게가 높고, 휴식시 맥박수도 높은 수준이지만, 혈당산소요구량은 반대로 낮은 수준

# %% [markdown]
# ---

# %% [markdown]
# ## Customizing

# %% [markdown]
# > 기본으로 제공되는 그래프 결과의 가독성 향상으 ㄹ위해 그래프 속성을 변경

# %%
ds_count = ds_fitness["AGEGROUP"].value_counts()
fig, axes = plt.subplots(nrows=2, ncols=2, figsize = (13,10))
plt.tight_layout(w_pad=5, h_pad=5)

#histogram
axes[0,0].hist(ds_fitness["OXY"])
axes[0,0].set_title("Histogram",fontsize=15)
axes[0,0].set_xlabel("혈당 산소 요구량",fontsize=12)

# pie Chart
axes[0,1].pie(ds_count,labels=ds_count.index.tolist(),autopct="%.1f%%")
axes[0,1].set_title("Pie Chart",fontsize=15)
axes[0,1].set_xlabel("나이그룹",fontsize=12)

# Trend
axes[1,0].plot("RUNTIME","RUNPULSE",data= ds_fitness,label="운동맥박")
axes[1,0].plot("RUNTIME","OXY",data= ds_fitness,label="혈당산소요구량")
axes[1,0].set_title("Trend",fontsize=15)
axes[1,0].set_xlabel("운동시간",fontsize=12)
axes[1,0].legend()

# Scatter
axes[1,1].scatter("RUNPULSE","OXY",data= ds_fitness,label="운동맥박")
axes[1,1].set_title("Scatter",fontsize=15)
axes[1,1].set_xlabel("운동맥박",fontsize=12)
axes[1,1].set_ylabel("혈당산소요구량",fontsize=12)
# Out:
# Text(486.9227272727271, 0.5, '혈당산소요구량')

# %%
ds_count = ds_fitness["AGEGROUP"].value_counts()
fig, axes = plt.subplots(nrows=4, ncols=1, figsize = (5,10))
plt.tight_layout(w_pad=5, h_pad=5)

#histogram
axes[0].hist(ds_fitness["OXY"])
axes[0].set_title("Histogram",fontsize=15)
axes[0].set_xlabel("혈당 산소 요구량",fontsize=12)

# pie Chart
axes[1].pie(ds_count,labels=ds_count.index.tolist(),autopct="%.1f%%")
axes[1].set_title("Pie Chart",fontsize=15)
axes[1].set_xlabel("나이그룹",fontsize=12)

# Trend
axes[2].plot("RUNTIME","RUNPULSE",data= ds_fitness,label="운동맥박")
axes[2].plot("RUNTIME","OXY",data= ds_fitness,label="혈당산소요구량")
axes[2].set_title("Trend",fontsize=15)
axes[2].set_xlabel("운동시간",fontsize=12)
axes[2].legend()

# Scatter
axes[3].scatter("RUNPULSE","OXY",data= ds_fitness,label="운동맥박")
axes[3].set_title("Scatter",fontsize=15)
axes[3].set_xlabel("운동맥박",fontsize=12)
axes[3].set_ylabel("혈당산소요구량",fontsize=12)
# Out:
# Text(19.25, 0.5, '혈당산소요구량')

# %%
ds_count = ds_fitness["AGEGROUP"].value_counts()
fig, axes = plt.subplots(nrows=1, ncols=4, figsize = (20,5))
plt.tight_layout(w_pad=5, h_pad=5)

#histogram
axes[0].hist(ds_fitness["OXY"])
axes[0].set_title("Histogram",fontsize=15)
axes[0].set_xlabel("혈당 산소 요구량",fontsize=12)

# pie Chart
axes[1].pie(ds_count,labels=ds_count.index.tolist(),autopct="%.1f%%")
axes[1].set_title("Pie Chart",fontsize=15)
axes[1].set_xlabel("나이그룹",fontsize=12)

# Trend
axes[2].plot("RUNTIME","RUNPULSE",data= ds_fitness,label="운동맥박")
axes[2].plot("RUNTIME","OXY",data= ds_fitness,label="혈당산소요구량")
axes[2].set_title("Trend",fontsize=15)
axes[2].set_xlabel("운동시간",fontsize=12)
axes[2].legend()

# Scatter
axes[3].scatter("RUNPULSE","OXY",data= ds_fitness,label="운동맥박")
axes[3].set_title("Scatter",fontsize=15)
axes[3].set_xlabel("운동맥박",fontsize=12)
axes[3].set_ylabel("혈당산소요구량",fontsize=12)
# Out:
# Text(1027.6413043478262, 0.5, '혈당산소요구량')
