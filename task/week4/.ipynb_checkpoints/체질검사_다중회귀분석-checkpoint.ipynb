# %%
def draw_multivarient_plot(dataset, rows, cols, plot_type):
    column_names=dataset.columns.values
    number_of_column=len(column_names)
    fig, axarr=plt.subplots(rows,cols, figsize=(5*cols,5*rows))

    counter=0
    for i in range(rows):
        for j in range(cols):
            if 'violin' in plot_type:
                sns.violinplot(y=column_names[counter],data=dataset, ax=axarr[i][j])
            elif 'box'in plot_type :
                sns.boxplot( y=column_names[counter],data=dataset, ax=axarr[i][j])
            elif 'point' in plot_type:
                sns.pointplot(y=column_names[counter],data=dataset, ax=axarr[i][j])
            elif 'bar' in plot_type:
                sns.barplot(y=column_names[counter],data=dataset, ax=axarr[i][j])

            counter+=1
            if counter==(number_of_column-1,):
                break

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as ols
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.eval_measures import rmse
from sklearn.preprocessing import scale
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.preprocessing import scale, minmax_scale

# %matplotlib inline

# %%
data = pd.read_csv("./체질검사.csv", engine='python')
data.head()
# Out:
#     FAT  AGE  WEIGHT  HEIGHT  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  \
# 0  35.2   46  363.15   72.25  51.2  136.2    148.1  147.7   87.3  49.1   29.6
# 1  11.8   27  168.00   71.25  38.1   93.0     79.1   94.5   57.3  36.2   24.5
# 2  22.2   69  177.75   68.50  38.7  102.0     95.0   98.3   55.0  38.3   21.8
# 3  10.6   57  147.75   65.75  35.2   99.6     86.4   90.1   53.0  35.0   21.3
# 4  47.5   51  219.00   64.00  41.2  119.8    122.1  112.8   62.5  36.9   23.6
#
#    BICEPS  FOREARM  WRIST
# 0    45.0     29.0   21.4
# 1    29.0     30.0   18.8
# 2    30.8     25.7   18.8
# 3    31.7     27.3   16.9
# 4    34.7     29.1   18.4

# %%
data.isnull().sum()
# Out:
# FAT        0
# AGE        0
# WEIGHT     0
# HEIGHT     0
# NECK       0
# CHEST      0
# ABDOMEN    0
# HIP        0
# THIGH      0
# KNEE       0
# ANKLE      0
# BICEPS     0
# FOREARM    0
# WRIST      0
# dtype: int64

# %%
data["KG"] = data.WEIGHT * 0.45
data["CM"] = data.HEIGHT * 2.54
data["BMI"] = data.KG / pow(data.CM/100,2)
data.drop(["WEIGHT","HEIGHT"],axis=1,inplace=True)

# %%
data.head()
# Out:
#     FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0  35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
# 1  11.8   27  38.1   93.0     79.1   94.5   57.3  36.2   24.5    29.0
# 2  22.2   69  38.7  102.0     95.0   98.3   55.0  38.3   21.8    30.8
# 3  10.6   57  35.2   99.6     86.4   90.1   53.0  35.0   21.3    31.7
# 4  47.5   51  41.2  119.8    122.1  112.8   62.5  36.9   23.6    34.7
#
#    FOREARM  WRIST        KG       CM        BMI
# 0     29.0   21.4  163.4175  183.515  48.523870
# 1     30.0   18.8   75.6000  180.975  23.082595
# 2     25.7   18.8   79.9875  173.990  26.422478
# 3     27.3   16.9   66.4875  167.005  23.838617
# 4     29.1   18.4   98.5500  162.560  37.293165

# %%
draw_multivarient_plot(data,4,4,"box_plot")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-148fc5fe614a> in <module>
# ----> 1 draw_multivarient_plot(data,4,4,"box_plot")
#
# <ipython-input-1-de7a76154fa8> in draw_multivarient_plot(dataset, rows, cols, plot_type)
#      10                 sns.violinplot(y=column_names[counter],data=dataset, ax=axarr[i][j])
#      11             elif 'box'in plot_type :
# ---> 12                 sns.boxplot( y=column_names[counter],data=dataset, ax=axarr[i][j])
#      13             elif 'point' in plot_type:
#      14                 sns.pointplot(y=column_names[counter],data=dataset, ax=axarr[i][j])
#
# IndexError: index 15 is out of bounds for axis 0 with size 15

# %%
data.describe()
# Out:
#             FAT         AGE        NECK       CHEST     ABDOMEN         HIP  \
# count  250.0000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean    19.0316   44.884000   37.944800  100.662000   92.286800   99.651200
# std      8.2940   12.652227    2.290454    8.153765   10.207444    6.443634
# min      0.0000   22.000000   31.100000   79.300000   69.400000   85.000000
# 25%     12.4250   35.250000   36.400000   94.250000   84.525000   95.500000
# 50%     19.2000   43.000000   38.000000   99.600000   90.900000   99.300000
# 75%     25.2000   54.000000   39.400000  105.300000   99.175000  103.175000
# max     47.5000   81.000000   43.900000  128.300000  126.200000  125.600000
#
#             THIGH        KNEE       ANKLE      BICEPS     FOREARM       WRIST  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean    59.249600   38.532800   23.074000   32.217200   28.662400   18.220400
# std      4.912309    2.314136    1.650436    2.922449    2.028677    0.913983
# min     47.200000   33.000000   19.100000   24.800000   21.000000   15.800000
# 25%     56.000000   36.925000   22.000000   30.200000   27.300000   17.600000
# 50%     58.950000   38.450000   22.800000   32.000000   28.700000   18.300000
# 75%     62.250000   39.875000   24.000000   34.300000   30.000000   18.800000
# max     74.400000   46.000000   33.900000   39.100000   34.900000   21.400000
#
#               KG          CM         BMI
# count  250.00000  250.000000  250.000000
# mean    80.13744  178.569620   25.091335
# std     12.16597    6.646277    3.320624
# min     53.32500  162.560000   17.874982
# 25%     71.32500  173.355000   22.853241
# 50%     79.25625  177.800000   24.822534
# 75%     88.53750  183.515000   27.064068
# max    118.23750  197.485000   38.774160

# %%
data[data["FAT"] > 40]
# Out:
#       FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 4    47.5   51  41.2  119.8    122.1  112.8   62.5  36.9   23.6    34.7
# 140  40.1   49  38.4  118.5    113.1  113.8   61.9  38.3   21.9    32.0
#
#      FOREARM  WRIST       KG      CM        BMI
# 4       29.1   18.4  98.5500  162.56  37.293165
# 140     29.8   17.0  86.2875  165.10  31.655833

# %%
data[data["NECK"] > 45]
# Out:
#     FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0  35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
#
#    FOREARM  WRIST        KG       CM       BMI
# 0     29.0   21.4  163.4175  183.515  48.52387

# %%
data[data["NECK"] < 32.5]
# Out:
#       FAT  AGE  NECK  CHEST  ABDOMEN   HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 33   18.0   43  31.1   93.1     87.3  96.6   54.7  39.0   24.8    31.0
# 174   7.7   39  31.5   85.1     76.0  88.2   50.0  34.7   21.0    26.1
#
#      FOREARM  WRIST       KG      CM        BMI
# 33      29.4   18.8  74.4750  173.99  24.601520
# 174     23.1   16.1  56.3625  172.72  18.893177

# %%
data[data["CHEST"] > 125]
# Out:
#      FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0   35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
# 82  34.5   45  43.2  128.3    126.2  125.6   72.5  39.6   26.6    36.4
#
#     FOREARM  WRIST        KG       CM       BMI
# 0      29.0   21.4  163.4175  183.515  48.52387
# 82     32.7   21.4  118.2375  174.625  38.77416

# %%
data[data["ABDOMEN"] > 120]
# Out:
#      FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0   35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
# 4   47.5   51  41.2  119.8    122.1  112.8   62.5  36.9   23.6    34.7
# 82  34.5   45  43.2  128.3    126.2  125.6   72.5  39.6   26.6    36.4
#
#     FOREARM  WRIST        KG       CM        BMI
# 0      29.0   21.4  163.4175  183.515  48.523870
# 4      29.1   18.4   98.5500  162.560  37.293165
# 82     32.7   21.4  118.2375  174.625  38.774160

# %%
data[data["HIP"] > 120]
# Out:
#      FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0   35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
# 82  34.5   45  43.2  128.3    126.2  125.6   72.5  39.6   26.6    36.4
#
#     FOREARM  WRIST        KG       CM       BMI
# 0      29.0   21.4  163.4175  183.515  48.52387
# 82     32.7   21.4  118.2375  174.625  38.77416

# %%
data[data["THIGH"] > 80]
# Out:
#     FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0  35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
#
#    FOREARM  WRIST        KG       CM       BMI
# 0     29.0   21.4  163.4175  183.515  48.52387

# %%
data[data["KNEE"] > 46]
# Out:
#     FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0  35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
#
#    FOREARM  WRIST        KG       CM       BMI
# 0     29.0   21.4  163.4175  183.515  48.52387

# %%
data[data["ANKLE"] > 28]
# Out:
#      FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0   35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
# 35  26.6   67  36.5   98.9     89.7   96.2   54.7  37.8   33.7    32.4
# 93  11.9   32  38.7  100.5     88.7   99.8   57.5  38.7   33.9    32.5
#
#     FOREARM  WRIST        KG       CM        BMI
# 0      29.0   21.4  163.4175  183.515  48.523870
# 35     27.7   18.2   75.1500  171.450  25.565483
# 93     27.7   18.4   81.9000  187.325  23.339547

# %%
data[data["BICEPS"] > 40]
# Out:
#     FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0  35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
#
#    FOREARM  WRIST        KG       CM       BMI
# 0     29.0   21.4  163.4175  183.515  48.52387

# %%
data[data["FOREARM"] > 34]
# Out:
#      FAT  AGE  NECK  CHEST  ABDOMEN   HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 73  12.5   30  35.9   88.7     76.6  89.8   50.1  34.8   21.8    27.0
#
#     FOREARM  WRIST      KG       CM        BMI
# 73     34.9   16.9  61.425  174.625  20.143379

# %%
data[data["FOREARM"] < 24]
# Out:
#       FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 48   12.5   55  33.4   88.8     78.2   87.5   50.8  33.0   19.7    25.3
# 114  25.3   36  41.5  115.3    108.8  114.4   69.2  42.4   24.0    35.4
# 174   7.7   39  31.5   85.1     76.0   88.2   50.0  34.7   21.0    26.1
# 177  16.6   44  41.9  105.6     96.3  102.0   63.3  39.8   24.1    37.3
#
#      FOREARM  WRIST        KG       CM        BMI
# 48      22.0   15.8   56.9250  169.545  19.803095
# 114     21.0   20.1  102.0375  182.245  30.721935
# 174     23.1   16.1   56.3625  172.720  18.893177
# 177     23.1   19.4   93.9375  185.420  27.322840

# %%
data[data["KG"] > 120]
# Out:
#     FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 0  35.2   46  51.2  136.2    148.1  147.7   87.3  49.1   29.6    45.0
#
#    FOREARM  WRIST        KG       CM       BMI
# 0     29.0   21.4  163.4175  183.515  48.52387

# %%
data[data["CM"] < 140]
# Out:
#      FAT  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 78  32.9   44  36.6  106.0    104.3  115.5   70.6  42.5   23.7    33.6
#
#     FOREARM  WRIST     KG     CM         BMI
# 78     28.7   17.4  92.25  74.93  164.306562

# %% [markdown]
# 확인 결과 78은 키가 비정상적으로 작은 것으로 보아 이상치로 판단된다.
# 0은 정상적인 데이터로 보이나, 너무 편향되어 있는 값을 가지고 있으므로 제거한다.

# %%
data.drop(0,0,inplace=True)
data.drop(78,0,inplace=True)

# %%
draw_multivarient_plot(data,4,4,"box_plot")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-148fc5fe614a> in <module>
# ----> 1 draw_multivarient_plot(data,4,4,"box_plot")
#
# <ipython-input-1-de7a76154fa8> in draw_multivarient_plot(dataset, rows, cols, plot_type)
#      10                 sns.violinplot(y=column_names[counter],data=dataset, ax=axarr[i][j])
#      11             elif 'box'in plot_type :
# ---> 12                 sns.boxplot( y=column_names[counter],data=dataset, ax=axarr[i][j])
#      13             elif 'point' in plot_type:
#      14                 sns.pointplot(y=column_names[counter],data=dataset, ax=axarr[i][j])
#
# IndexError: index 15 is out of bounds for axis 0 with size 15

# %%
data.describe()
# Out:
#             FAT         AGE        NECK       CHEST     ABDOMEN         HIP  \
# count  250.0000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean    19.0316   44.884000   37.944800  100.662000   92.286800   99.651200
# std      8.2940   12.652227    2.290454    8.153765   10.207444    6.443634
# min      0.0000   22.000000   31.100000   79.300000   69.400000   85.000000
# 25%     12.4250   35.250000   36.400000   94.250000   84.525000   95.500000
# 50%     19.2000   43.000000   38.000000   99.600000   90.900000   99.300000
# 75%     25.2000   54.000000   39.400000  105.300000   99.175000  103.175000
# max     47.5000   81.000000   43.900000  128.300000  126.200000  125.600000
#
#             THIGH        KNEE       ANKLE      BICEPS     FOREARM       WRIST  \
# count  250.000000  250.000000  250.000000  250.000000  250.000000  250.000000
# mean    59.249600   38.532800   23.074000   32.217200   28.662400   18.220400
# std      4.912309    2.314136    1.650436    2.922449    2.028677    0.913983
# min     47.200000   33.000000   19.100000   24.800000   21.000000   15.800000
# 25%     56.000000   36.925000   22.000000   30.200000   27.300000   17.600000
# 50%     58.950000   38.450000   22.800000   32.000000   28.700000   18.300000
# 75%     62.250000   39.875000   24.000000   34.300000   30.000000   18.800000
# max     74.400000   46.000000   33.900000   39.100000   34.900000   21.400000
#
#               KG          CM         BMI
# count  250.00000  250.000000  250.000000
# mean    80.13744  178.569620   25.091335
# std     12.16597    6.646277    3.320624
# min     53.32500  162.560000   17.874982
# 25%     71.32500  173.355000   22.853241
# 50%     79.25625  177.800000   24.822534
# 75%     88.53750  183.515000   27.064068
# max    118.23750  197.485000   38.774160

# %%
data[data["ANKLE"] > 32]
# Out:
#      FAT  AGE  NECK  CHEST  ABDOMEN   HIP  THIGH  KNEE  ANKLE  BICEPS  \
# 35  26.6   67  36.5   98.9     89.7  96.2   54.7  37.8   33.7    32.4
# 93  11.9   32  38.7  100.5     88.7  99.8   57.5  38.7   33.9    32.5
#
#     FOREARM  WRIST     KG       CM        BMI
# 35     27.7   18.2  75.15  171.450  25.565483
# 93     27.7   18.4  81.90  187.325  23.339547

# %% [markdown]
# 위의 두 항목은 ANKLE(발목둘레)을 제외한 모든 값들이 평균 근처이다.
# 한국의 경우 성인 남성 발목둘레 평균은 약 25.7 이고 최대값은 31 이다.
# 이상치로 판단하여 제거한다.

# %%
data.drop(data[data["ANKLE"] > 32].index, inplace=True)

# %%
draw_multivarient_plot(data,4,4,"box_plot")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-148fc5fe614a> in <module>
# ----> 1 draw_multivarient_plot(data,4,4,"box_plot")
#
# <ipython-input-1-de7a76154fa8> in draw_multivarient_plot(dataset, rows, cols, plot_type)
#      10                 sns.violinplot(y=column_names[counter],data=dataset, ax=axarr[i][j])
#      11             elif 'box'in plot_type :
# ---> 12                 sns.boxplot( y=column_names[counter],data=dataset, ax=axarr[i][j])
#      13             elif 'point' in plot_type:
#      14                 sns.pointplot(y=column_names[counter],data=dataset, ax=axarr[i][j])
#
# IndexError: index 15 is out of bounds for axis 0 with size 15

# %%
data.head()
# Out:
#     FAT  AGE  WEIGHT  HEIGHT  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  ANKLE  \
# 0  35.2   46  363.15   72.25  51.2  136.2    148.1  147.7   87.3  49.1   29.6
# 1  11.8   27  168.00   71.25  38.1   93.0     79.1   94.5   57.3  36.2   24.5
# 2  22.2   69  177.75   68.50  38.7  102.0     95.0   98.3   55.0  38.3   21.8
# 3  10.6   57  147.75   65.75  35.2   99.6     86.4   90.1   53.0  35.0   21.3
# 4  47.5   51  219.00   64.00  41.2  119.8    122.1  112.8   62.5  36.9   23.6
#
#    BICEPS  FOREARM  WRIST
# 0    45.0     29.0   21.4
# 1    29.0     30.0   18.8
# 2    30.8     25.7   18.8
# 3    31.7     27.3   16.9
# 4    34.7     29.1   18.4

# %%
data.drop(["KG","CM"],axis=1,inplace=True)
df_x = data.drop("FAT",axis=1,inplace=False)
df_y = data['FAT']

# %%
sns.pairplot(data)

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(),annot=True, fmt='.2f')

# %%
df_x_const = sm.add_constant(df_x)
# Out:
# /home/donghyun-lee/miniconda3/envs/DS/lib/python3.6/site-packages/numpy/core/fromnumeric.py:2223: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
df_vif = pd.DataFrame()
df_vif["variable"] = df_x_const.columns
df_vif["vif"] = [variance_inflation_factor(df_x_const.values,i) for i in range(df_x_const.shape[1])]
df_vif.sort_values("vif", inplace=True)
df_vif.round(3)
# Out:
#    variable      vif
# 8     ANKLE    1.760
# 1       AGE    2.071
# 10  FOREARM    2.414
# 11    WRIST    3.101
# 9    BICEPS    3.294
# 2      NECK    3.682
# 7      KNEE    4.108
# 6     THIGH    7.061
# 3     CHEST    8.839
# 5       HIP    9.744
# 12      BMI   10.479
# 4   ABDOMEN   11.494
# 0     const  799.542

# %%
reg_multi_model = sm.OLS(df_y, df_x_const)
reg_multi_res = reg_multi_model.fit()
print(reg_multi_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FAT   R-squared:                       0.751
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     59.44
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.81e-64
# Time:                        14:49:20   Log-Likelihood:                -709.53
# No. Observations:                 250   AIC:                             1445.
# Df Residuals:                     237   BIC:                             1491.
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.3520      7.592      0.441      0.659     -11.605      18.309
# AGE            0.0837      0.031      2.736      0.007       0.023       0.144
# NECK          -0.4710      0.225     -2.089      0.038      -0.915      -0.027
# CHEST         -0.2015      0.098     -2.054      0.041      -0.395      -0.008
# ABDOMEN        0.8571      0.089      9.591      0.000       0.681       1.033
# HIP           -0.2633      0.130     -2.020      0.044      -0.520      -0.007
# THIGH          0.1505      0.146      1.034      0.302      -0.136       0.437
# KNEE          -0.0961      0.236     -0.408      0.684      -0.560       0.368
# ANKLE          0.1205      0.216      0.557      0.578      -0.306       0.547
# BICEPS         0.1367      0.167      0.818      0.414      -0.192       0.466
# FOREARM        0.2351      0.206      1.141      0.255      -0.171       0.641
# WRIST         -1.9568      0.518     -3.775      0.000      -2.978      -0.936
# BMI            0.5475      0.262      2.088      0.038       0.031       1.064
# ==============================================================================
# Omnibus:                        4.310   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.116   Jarque-Bera (JB):                2.808
# Skew:                           0.040   Prob(JB):                        0.246
# Kurtosis:                       2.487   Cond. No.                     5.70e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.7e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_x_const.head()
# Out:
#    const  AGE  NECK  CHEST  ABDOMEN    HIP  THIGH  KNEE  BICEPS  FOREARM  \
# 1    1.0   27  38.1   93.0     79.1   94.5   57.3  36.2    29.0     30.0
# 2    1.0   69  38.7  102.0     95.0   98.3   55.0  38.3    30.8     25.7
# 3    1.0   57  35.2   99.6     86.4   90.1   53.0  35.0    31.7     27.3
# 4    1.0   51  41.2  119.8    122.1  112.8   62.5  36.9    34.7     29.1
# 5    1.0   40  38.5  106.5    100.9  106.2   63.5  39.9    35.1     30.6
#
#    WRIST        BMI
# 1   18.8  23.082595
# 2   18.8  26.422478
# 3   16.9  23.838617
# 4   18.4  37.293165
# 5   19.0  28.789726

# %%
df_x_const = df_x_const.drop(["ANKLE"],axis=1,inplace=False)
df_vif = pd.DataFrame()
df_vif["variable"] = df_x_const.columns
df_vif["vif"] = [variance_inflation_factor(df_x_const.values,i) for i in range(df_x_const.shape[1])]
df_vif.sort_values("vif", inplace=True)
df_vif.round(3)
# Out:
#    variable      vif
# 1       AGE    2.012
# 9   FOREARM    2.414
# 10    WRIST    2.846
# 8    BICEPS    3.293
# 2      NECK    3.661
# 7      KNEE    3.837
# 6     THIGH    7.058
# 3     CHEST    8.832
# 5       HIP    9.742
# 11      BMI   10.410
# 4   ABDOMEN   11.424
# 0     const  791.848

# %%
reg_multi_model = sm.OLS(df_y, df_x_const)
reg_multi_res = reg_multi_model.fit()
print(reg_multi_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FAT   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     65.01
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.55e-65
# Time:                        14:56:10   Log-Likelihood:                -709.69
# No. Observations:                 250   AIC:                             1443.
# Df Residuals:                     238   BIC:                             1486.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.7669      7.545      0.499      0.618     -11.096      18.630
# AGE            0.0808      0.030      2.684      0.008       0.022       0.140
# NECK          -0.4804      0.224     -2.140      0.033      -0.923      -0.038
# CHEST         -0.1999      0.098     -2.042      0.042      -0.393      -0.007
# ABDOMEN        0.8532      0.089      9.591      0.000       0.678       1.028
# HIP           -0.2623      0.130     -2.016      0.045      -0.519      -0.006
# THIGH          0.1489      0.145      1.025      0.307      -0.137       0.435
# KNEE          -0.0624      0.227     -0.274      0.784      -0.510       0.386
# BICEPS         0.1352      0.167      0.810      0.419      -0.193       0.464
# FOREARM        0.2349      0.206      1.142      0.255      -0.170       0.640
# WRIST         -1.8741      0.496     -3.779      0.000      -2.851      -0.897
# BMI            0.5594      0.261      2.143      0.033       0.045       1.074
# ==============================================================================
# Omnibus:                        4.432   Durbin-Watson:                   2.083
# Prob(Omnibus):                  0.109   Jarque-Bera (JB):                2.890
# Skew:                           0.054   Prob(JB):                        0.236
# Kurtosis:                       2.484   Cond. No.                     5.63e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_x_const = df_x_const.drop(["KNEE"],axis=1,inplace=False)
df_vif = pd.DataFrame()
df_vif["variable"] = df_x_const.columns
df_vif["vif"] = [variance_inflation_factor(df_x_const.values,i) for i in range(df_x_const.shape[1])]
df_vif.sort_values("vif", inplace=True)
df_vif.round(3)
# Out:
#    variable      vif
# 1       AGE    1.973
# 8   FOREARM    2.392
# 9     WRIST    2.687
# 7    BICEPS    3.293
# 2      NECK    3.656
# 6     THIGH    6.323
# 3     CHEST    8.691
# 5       HIP    9.014
# 10      BMI    9.578
# 4   ABDOMEN   11.384
# 0     const  791.840

# %%
reg_multi_model = sm.OLS(df_y, df_x_const)
reg_multi_res = reg_multi_model.fit()
print(reg_multi_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FAT   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     71.78
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           3.04e-66
# Time:                        14:56:45   Log-Likelihood:                -709.73
# No. Observations:                 250   AIC:                             1441.
# Df Residuals:                     239   BIC:                             1480.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.7735      7.530      0.501      0.617     -11.061      18.608
# AGE            0.0797      0.030      2.677      0.008       0.021       0.138
# NECK          -0.4781      0.224     -2.136      0.034      -0.919      -0.037
# CHEST         -0.2033      0.097     -2.097      0.037      -0.394      -0.012
# ABDOMEN        0.8517      0.089      9.610      0.000       0.677       1.026
# HIP           -0.2721      0.125     -2.178      0.030      -0.518      -0.026
# THIGH          0.1360      0.137      0.991      0.323      -0.134       0.406
# BICEPS         0.1351      0.167      0.811      0.418      -0.193       0.463
# FOREARM        0.2296      0.204      1.123      0.263      -0.173       0.632
# WRIST         -1.9063      0.481     -3.964      0.000      -2.854      -0.959
# BMI            0.5796      0.250      2.319      0.021       0.087       1.072
# ==============================================================================
# Omnibus:                        4.799   Durbin-Watson:                   2.084
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                3.056
# Skew:                           0.058   Prob(JB):                        0.217
# Kurtosis:                       2.471   Cond. No.                     5.53e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.53e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_x_const = df_x_const.drop(["BICEPS"],axis=1,inplace=False)
df_vif = pd.DataFrame()
df_vif["variable"] = df_x_const.columns
df_vif["vif"] = [variance_inflation_factor(df_x_const.values,i) for i in range(df_x_const.shape[1])]
df_vif.sort_values("vif", inplace=True)
df_vif.round(3)
# Out:
#   variable      vif
# 1      AGE    1.972
# 7  FOREARM    2.175
# 8    WRIST    2.671
# 2     NECK    3.605
# 6    THIGH    5.860
# 3    CHEST    8.541
# 5      HIP    9.013
# 9      BMI    9.518
# 4  ABDOMEN   11.258
# 0    const  775.067

# %%
reg_multi_model = sm.OLS(df_y, df_x_const)
reg_multi_res = reg_multi_model.fit()
print(reg_multi_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FAT   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     79.79
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           4.57e-67
# Time:                        14:57:14   Log-Likelihood:                -710.07
# No. Observations:                 250   AIC:                             1440.
# Df Residuals:                     240   BIC:                             1475.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8843      7.445      0.387      0.699     -11.781      17.550
# AGE            0.0803      0.030      2.700      0.007       0.022       0.139
# NECK          -0.4567      0.222     -2.056      0.041      -0.894      -0.019
# CHEST         -0.1930      0.096     -2.009      0.046      -0.382      -0.004
# ABDOMEN        0.8442      0.088      9.584      0.000       0.671       1.018
# HIP           -0.2732      0.125     -2.189      0.030      -0.519      -0.027
# THIGH          0.1661      0.132      1.258      0.210      -0.094       0.426
# FOREARM        0.2795      0.195      1.435      0.153      -0.104       0.663
# WRIST         -1.8762      0.479     -3.916      0.000      -2.820      -0.932
# BMI            0.5957      0.249      2.393      0.017       0.105       1.086
# ==============================================================================
# Omnibus:                        4.512   Durbin-Watson:                   2.070
# Prob(Omnibus):                  0.105   Jarque-Bera (JB):                2.967
# Skew:                           0.069   Prob(JB):                        0.227
# Kurtosis:                       2.484   Cond. No.                     5.40e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.4e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_x_const = df_x_const.drop(["THIGH"],axis=1,inplace=False)
df_vif = pd.DataFrame()
df_vif["variable"] = df_x_const.columns
df_vif["vif"] = [variance_inflation_factor(df_x_const.values,i) for i in range(df_x_const.shape[1])]
df_vif.sort_values("vif", inplace=True)
df_vif.round(3)
# Out:
#   variable      vif
# 1      AGE    1.734
# 6  FOREARM    2.161
# 7    WRIST    2.670
# 2     NECK    3.529
# 5      HIP    6.669
# 3    CHEST    8.244
# 8      BMI    9.021
# 4  ABDOMEN   11.230
# 0    const  774.526

# %%
reg_multi_model = sm.OLS(df_y, df_x_const)
reg_multi_res = reg_multi_model.fit()
print(reg_multi_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FAT   R-squared:                       0.748
# Model:                            OLS   Adj. R-squared:                  0.739
# Method:                 Least Squares   F-statistic:                     89.35
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           1.02e-67
# Time:                        14:57:53   Log-Likelihood:                -710.90
# No. Observations:                 250   AIC:                             1440.
# Df Residuals:                     241   BIC:                             1471.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.1316      7.451      0.420      0.675     -11.546      17.809
# AGE            0.0673      0.028      2.411      0.017       0.012       0.122
# NECK          -0.4161      0.220     -1.891      0.060      -0.850       0.017
# CHEST         -0.2155      0.094     -2.281      0.023      -0.402      -0.029
# ABDOMEN        0.8497      0.088      9.648      0.000       0.676       1.023
# HIP           -0.1931      0.108     -1.796      0.074      -0.405       0.019
# FOREARM        0.2993      0.194      1.540      0.125      -0.084       0.682
# WRIST         -1.8734      0.480     -3.906      0.000      -2.818      -0.929
# BMI            0.6673      0.243      2.750      0.006       0.189       1.145
# ==============================================================================
# Omnibus:                        5.722   Durbin-Watson:                   2.062
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                3.417
# Skew:                           0.054   Prob(JB):                        0.181
# Kurtosis:                       2.438   Cond. No.                     5.13e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.13e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_x_const = df_x_const.drop(["FOREARM"],axis=1,inplace=False)
df_vif = pd.DataFrame()
df_vif["variable"] = df_x_const.columns
df_vif["vif"] = [variance_inflation_factor(df_x_const.values,i) for i in range(df_x_const.shape[1])]
df_vif.sort_values("vif", inplace=True)
df_vif.round(3)
# Out:
#   variable      vif
# 1      AGE    1.675
# 6    WRIST    2.538
# 2     NECK    3.328
# 5      HIP    6.651
# 3    CHEST    8.187
# 7      BMI    8.847
# 4  ABDOMEN   11.052
# 0    const  767.888

# %%
reg_multi_model = sm.OLS(df_y, df_x_const)
reg_multi_res = reg_multi_model.fit()
print(reg_multi_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FAT   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.738
# Method:                 Least Squares   F-statistic:                     101.2
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           3.15e-68
# Time:                        14:58:13   Log-Likelihood:                -712.12
# No. Observations:                 250   AIC:                             1440.
# Df Residuals:                     242   BIC:                             1468.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.1939      7.440      0.564      0.573     -10.462      18.850
# AGE            0.0594      0.028      2.158      0.032       0.005       0.114
# NECK          -0.3351      0.214     -1.564      0.119      -0.757       0.087
# CHEST         -0.2034      0.094     -2.155      0.032      -0.389      -0.017
# ABDOMEN        0.8326      0.088      9.503      0.000       0.660       1.005
# HIP           -0.1845      0.108     -1.714      0.088      -0.397       0.028
# WRIST         -1.7087      0.469     -3.644      0.000      -2.632      -0.785
# BMI            0.7192      0.241      2.984      0.003       0.245       1.194
# ==============================================================================
# Omnibus:                        6.899   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                3.859
# Skew:                           0.056   Prob(JB):                        0.145
# Kurtosis:                       2.402   Cond. No.                     5.05e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.05e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_x_const = df_x_const.drop(["NECK"],axis=1,inplace=False)
df_vif = pd.DataFrame()
df_vif["variable"] = df_x_const.columns
df_vif["vif"] = [variance_inflation_factor(df_x_const.values,i) for i in range(df_x_const.shape[1])]
df_vif.sort_values("vif", inplace=True)
df_vif.round(3)
# Out:
#   variable      vif
# 1      AGE    1.659
# 5    WRIST    1.980
# 4      HIP    6.647
# 2    CHEST    7.919
# 6      BMI    8.704
# 3  ABDOMEN   11.029
# 0    const  729.202

# %%
reg_multi_model = sm.OLS(df_y, df_x_const)
reg_multi_res = reg_multi_model.fit()
print(reg_multi_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FAT   R-squared:                       0.743
# Model:                            OLS   Adj. R-squared:                  0.736
# Method:                 Least Squares   F-statistic:                     117.0
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           9.33e-69
# Time:                        14:58:39   Log-Likelihood:                -713.38
# No. Observations:                 250   AIC:                             1441.
# Df Residuals:                     243   BIC:                             1465.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.5818      7.272      0.218      0.828     -12.742      15.906
# AGE            0.0636      0.027      2.317      0.021       0.010       0.118
# CHEST         -0.2302      0.093     -2.471      0.014      -0.414      -0.047
# ABDOMEN        0.8264      0.088      9.414      0.000       0.653       0.999
# HIP           -0.1801      0.108     -1.669      0.096      -0.393       0.033
# WRIST         -2.0526      0.415     -4.941      0.000      -2.871      -1.234
# BMI            0.6713      0.240      2.800      0.006       0.199       1.144
# ==============================================================================
# Omnibus:                        7.391   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):                3.981
# Skew:                           0.037   Prob(JB):                        0.137
# Kurtosis:                       2.386   Cond. No.                     4.81e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.81e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_x_const = df_x_const.drop(["HIP"],axis=1,inplace=False)
df_vif = pd.DataFrame()
df_vif["variable"] = df_x_const.columns
df_vif["vif"] = [variance_inflation_factor(df_x_const.values,i) for i in range(df_x_const.shape[1])]
df_vif.sort_values("vif", inplace=True)
df_vif.round(3)
# Out:
#   variable      vif
# 1      AGE    1.159
# 4    WRIST    1.761
# 2    CHEST    7.914
# 5      BMI    8.344
# 3  ABDOMEN    8.381
# 0    const  511.707

# %%
reg_multi_model = sm.OLS(df_y, df_x_const)
reg_multi_res = reg_multi_model.fit()
print(reg_multi_res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FAT   R-squared:                       0.740
# Model:                            OLS   Adj. R-squared:                  0.735
# Method:                 Least Squares   F-statistic:                     138.8
# Date:                Fri, 08 Feb 2019   Prob (F-statistic):           2.98e-69
# Time:                        14:59:03   Log-Likelihood:                -714.80
# No. Observations:                 250   AIC:                             1442.
# Df Residuals:                     244   BIC:                             1463.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -5.0447      6.114     -0.825      0.410     -17.087       6.998
# AGE            0.0888      0.023      3.855      0.000       0.043       0.134
# CHEST         -0.2260      0.093     -2.419      0.016      -0.410      -0.042
# ABDOMEN        0.7546      0.077      9.825      0.000       0.603       0.906
# WRIST         -2.2832      0.393     -5.807      0.000      -3.058      -1.509
# BMI            0.5899      0.236      2.504      0.013       0.126       1.054
# ==============================================================================
# Omnibus:                        7.896   Durbin-Watson:                   2.056
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                4.116
# Skew:                           0.010   Prob(JB):                        0.128
# Kurtosis:                       2.372   Cond. No.                     3.35e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.35e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
df_reg_coef = pd.DataFrame({"Coef":reg_multi_res.params.values[1:]},index=reg_multi_model.exog_names[1:])
df_reg_coef.plot.barh(y="Coef",legend=False)

# %%
df_x_scaled = scale(df_x_const)
reg_scaled_model = sm.OLS(df_y,df_x_scaled)
reg_scaled_res = reg_scaled_model.fit()
df_reg_scaled_coef = pd.DataFrame({"Coef": reg_scaled_res.params.values[1:]},index=reg_multi_model.exog_names[1:])
df_reg_scaled_coef.plot.barh(y="Coef",legend=False)
# Out:
# /home/donghyun-lee/miniconda3/envs/DS/lib/python3.6/site-packages/ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by the scale function.
#   """Entry point for launching an IPython kernel.

# %%
obs = reg_multi_res.resid.values
sns.residplot(obs,df_y)
obs.shape
# Out:
# (250,)

# %%
stats.probplot(obs, dist="norm",plot=plt)
# Out:
# ((array([-2.77398064, -2.47188227, -2.30034444, -2.17785208, -2.08131167,
#          -2.00098761, -1.93181728, -1.87081737, -1.81607586, -1.76629081,
#          -1.72053405, -1.67811963, -1.63852567, -1.60134548, -1.56625574,
#          -1.53299497, -1.50134856, -1.47113811, -1.44221367, -1.41444787,
#          -1.38773163, -1.36197075, -1.33708328, -1.3129975 , -1.28965023,
#          -1.26698552, -1.24495361, -1.22350997, -1.20261465, -1.18223161,
#          -1.16232826, -1.14287501, -1.12384491, -1.10521333, -1.08695771,
#          -1.06905733, -1.05149311, -1.03424742, -1.01730397, -1.00064765,
#          -0.98426442, -0.9681412 , -0.95226581, -0.93662686, -0.9212137 ,
#          -0.90601634, -0.8910254 , -0.87623208, -0.86162807, -0.84720556,
#          -0.83295716, -0.81887589, -0.80495514, -0.79118867, -0.77757053,
#          -0.76409509, -0.750757  , -0.73755115, -0.72447269, -0.71151699,
#          -0.69867964, -0.68595641, -0.67334326, -0.66083634, -0.64843195,
#          -0.63612654, -0.62391671, -0.6117992 , -0.59977086, -0.58782867,
#          -0.57596974, -0.56419127, -0.55249055, -0.54086499, -0.52931208,
#          -0.51782938, -0.50641456, -0.49506535, -0.48377955, -0.47255504,
#          -0.46138975, -0.45028169, -0.43922891, -0.42822954, -0.41728173,
#          -0.40638371, -0.39553374, -0.38473014, -0.37397126, -0.3632555 ,
#          -0.35258128, -0.34194709, -0.33135143, -0.32079284, -0.3102699 ,
#          -0.2997812 , -0.28932538, -0.27890109, -0.26850702, -0.25814189,
#          -0.24780441, -0.23749335, -0.22720747, -0.21694558, -0.20670649,
#          -0.19648902, -0.18629202, -0.17611436, -0.1659549 , -0.15581255,
#          -0.1456862 , -0.13557477, -0.12547718, -0.11539237, -0.10531928,
#          -0.09525687, -0.08520409, -0.07515992, -0.06512332, -0.05509328,
#          -0.04506878, -0.03504881, -0.02503235, -0.01501841, -0.00500597,
#           0.00500597,  0.01501841,  0.02503235,  0.03504881,  0.04506878,
#           0.05509328,  0.06512332,  0.07515992,  0.08520409,  0.09525687,
#           0.10531928,  0.11539237,  0.12547718,  0.13557477,  0.1456862 ,
#           0.15581255,  0.1659549 ,  0.17611436,  0.18629202,  0.19648902,
#           0.20670649,  0.21694558,  0.22720747,  0.23749335,  0.24780441,
#           0.25814189,  0.26850702,  0.27890109,  0.28932538,  0.2997812 ,
#           0.3102699 ,  0.32079284,  0.33135143,  0.34194709,  0.35258128,
#           0.3632555 ,  0.37397126,  0.38473014,  0.39553374,  0.40638371,
#           0.41728173,  0.42822954,  0.43922891,  0.45028169,  0.46138975,
#           0.47255504,  0.48377955,  0.49506535,  0.50641456,  0.51782938,
#           0.52931208,  0.54086499,  0.55249055,  0.56419127,  0.57596974,
